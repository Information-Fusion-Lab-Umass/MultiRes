# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))

if module_path not in sys.path:
    sys.path.append(module_path)

from IPython.display import display
import pandas as pd
import numpy as np

from src.data_processing.student_life_binned_aggregator import student_data, student_data_flattened

# %%
print(len(student_data))

activity_data = student_data[0]
audio_data = student_data[1]
activity_data = activity_data.iloc[:500, ]
audio_data = audio_data.iloc[:500, ]

audio_data.drop("student_id", axis=1, inplace=True)
activity_data.drop("student_id", axis=1, inplace=True)
# Out:
# 8
# /home/abhinav/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
display(student_data_flattened[student_data_flattened['stress_level_mode'].notnull()])
# Out:
#              0  activity_inference_min  activity_inference_max  \
# 2013-03-28  35                    -1.0                    -1.0
# 2013-03-29  35                     0.0                     0.0
# 2013-03-30  35                     0.0                     0.0
# 2013-03-31  35                     0.0                     0.0
# 2013-04-01  35                     0.0                     0.0
# 2013-04-02  35                     0.0                     0.0
# 2013-04-03  35                     0.0                     0.0
# 2013-04-04  35                    -1.0                    -1.0
# 2013-04-05  35                    -1.0                    -1.0
# 2013-04-06  35                    -1.0                    -1.0
# 2013-04-07  35                    -1.0                    -1.0
# 2013-04-08  35                    -1.0                    -1.0
# 2013-04-09  35                    -1.0                    -1.0
# 2013-04-10  35                    -1.0                    -1.0
# ...

# %%
display(student_data_flattened[student_data_flattened['conv_duration_min_sum'].notnull()].head(5))
# Out:
#                       0  activity_inference_min  activity_inference_max  \
# 2013-03-27 15:00:00  35                    -1.0                    -1.0
# 2013-03-27 16:00:00  35                    -1.0                    -1.0
# 2013-03-27 17:00:00  35                    -1.0                    -1.0
# 2013-03-27 18:00:00  35                    -1.0                    -1.0
# 2013-03-27 19:00:00  35                    -1.0                    -1.0
#
#                      activity_inference_count  activity_inference_mode  \
# 2013-03-27 15:00:00                         0                       -1
# 2013-03-27 16:00:00                         0                       -1
# 2013-03-27 17:00:00                         0                       -1
# 2013-03-27 18:00:00                         0                       -1
# 2013-03-27 19:00:00                         0                       -1
#
#                      audio_activity_inference_min  \
# 2013-03-27 15:00:00                          -1.0
# ...

# %%
display(student_data_flattened[student_data_flattened['phonecharge_duration_min_sum'].notnull()].head(5))
# Out:
#                       0  activity_inference_min  activity_inference_max  \
# 2013-03-29 00:00:00  35                     0.0                     0.0
# 2013-03-29 12:00:00  35                     0.0                     0.0
# 2013-03-30 00:00:00  35                     0.0                     0.0
# 2013-03-30 12:00:00  35                     0.0                     0.0
# 2013-03-31 00:00:00  35                     0.0                     0.0
#
#                      activity_inference_count  activity_inference_mode  \
# 2013-03-29 00:00:00                        19                        0
# 2013-03-29 12:00:00                        19                        0
# 2013-03-30 00:00:00                        22                        0
# 2013-03-30 12:00:00                        19                        0
# 2013-03-31 00:00:00                        19                        0
#
#                      audio_activity_inference_min  \
# 2013-03-29 00:00:00                          -1.0
# ...

# %%
display(student_data_flattened['stress_level_mode'].head())
# Out:
# 2013-03-27 04:02:00   NaN
# 2013-03-27 04:03:00   NaN
# 2013-03-27 04:04:00   NaN
# 2013-03-27 04:05:00   NaN
# 2013-03-27 04:06:00   NaN
# Freq: T, Name: stress_level_mode, dtype: float64

# %%
missing_val = student_data_flattened.isnull()
display(missing_val.head(5))
# Out:
#                          0  activity_inference_min  activity_inference_max  \
# 2013-03-27 04:02:00  False                   False                   False
# 2013-03-27 04:03:00  False                   False                   False
# 2013-03-27 04:04:00  False                   False                   False
# 2013-03-27 04:05:00  False                   False                   False
# 2013-03-27 04:06:00  False                   False                   False
#
#                      activity_inference_count  activity_inference_mode  \
# 2013-03-27 04:02:00                     False                    False
# 2013-03-27 04:03:00                     False                    False
# 2013-03-27 04:04:00                     False                    False
# 2013-03-27 04:05:00                     False                    False
# 2013-03-27 04:06:00                     False                    False
#
#                      audio_activity_inference_min  \
# ...
